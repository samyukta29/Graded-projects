# %% [markdown]
# ## Census Income Project

# %% [markdown]
# **Problem Statement:**
#
#
# This data was extracted from the 1994 Census bureau database by Ronny Kohavi and Barry Becker (Data Mining and Visualization, Silicon Graphics). A set of reasonably clean records was extracted using the following conditions:
# ((AAGE>16) && (AGI>100) && (AFNLWGT>1) && (HRSWK>0)). The prediction task is to determine whether a person makes over $50K a year.
#
# Description of fnlwgt (final weight)
# The weights on the Current Population Survey (CPS) files are controlled to independent estimates of the civilian non-institutional population of the US. These are prepared monthly for us by Population Division here at the Census Bureau. We use 3 sets of controls. These are:
# * A single cell estimate of the population 16+ for each state.
# * Controls for Hispanic Origin by age and sex.
# * Controls by Race, age and sex.
#
# We use all three sets of controls in our weighting program and "rake" through them 6 times so that by the end we come back to all the controls we used. The term estimate refers to population totals derived from CPS by creating "weighted tallies" of any specified socio-economic characteristics of the population. People with similar demographic characteristics should have similar weights. There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.

# %%
#importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
#from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.naive_bayes import GaussianNB as NB
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# %%
# to import dataset
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
#to check column names
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
#info about the data shape of data,type of individual columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# The dataframe has 15 columns and 32560 rows. 9 columns have object and 6 int64 data types.Dataset has no null values.

# %%
# to check for categorical columns
obj_columns = []

for i in df.dtypes.index:
    if df.dtypes[i] == "O":
        obj_columns.append(i)
obj_columns
# Out:
# ['Workclass',
#  'Education',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Native_country',
#  'Income']

# %%
# # to check for numerical columns
num_columns = [] 

for i in df.dtypes.index:
    if df.dtypes[i] != "O":
        num_columns.append(i)
num_columns
# Out:
# ['Age',
#  'Fnlwgt',
#  'Education_num',
#  'Capital_gain',
#  'Capital_loss',
#  'Hours_per_week']

# %%
# listing all Categorical data using for_loop method
for x in obj_columns:
    print(x)
    print(df[x].value_counts())
    print("-"*70)
# Out:
# Workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# ----------------------------------------------------------------------
# Education
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64
# ----------------------------------------------------------------------
# Marital_status
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64
# ----------------------------------------------------------------------
# Occupation
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64
# ----------------------------------------------------------------------
# Relationship
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64
# ----------------------------------------------------------------------
# Race
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64
# ----------------------------------------------------------------------
# Sex
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64
# ----------------------------------------------------------------------
# Native_country
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Thailand                         18
#  Laos                             18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Native_country, dtype: int64
# ----------------------------------------------------------------------
# Income
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64
# ----------------------------------------------------------------------

# %% [markdown]
#  * There are some '?' entries in Workclass, Occupation and Native_country column.
#
# * replacing'?' with the mode of the above columns, as they are categorical columns.

# %%
# to check the mode of Workclass column 
df["Workclass"].mode()  # we will fill the '?' values with this mode value
# Out:
# 0     Private
# dtype: object

# %%
# Replacing '?' with mode value
df['Workclass'] = df.Workclass.str.replace('?', 'Private')

# %%
# to check the mode of Native_country column 
df["Native_country"].mode()  # we will fill the '?' values with this
# Out:
# 0     United-States
# dtype: object

# %%
# Replacing '?' with mode value
df['Native_country'] = df.Native_country.str.replace('?', 'United-States')

# %% [markdown]
# I have replaced all '?' with there respective mode values.

# %%
# to Check the value count of Capital_gain column
df["Capital_gain"].value_counts()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 4931         1
# 1455         1
# 6097         1
# 22040        1
# 1111         1
# Name: Capital_gain, Length: 119, dtype: int64

# %% [markdown]
# In this perticular Capital_gain column there are 92% zero values so let me drop this column.

# %%
#Droping Capital_gain column
df = df.drop(["Capital_gain"],axis=1)

# %%
#Checking the value count of Capital_loss column
df["Capital_loss"].value_counts()
# Out:
# 0       31041
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 1411        1
# 1539        1
# 2472        1
# 1944        1
# 2201        1
# Name: Capital_loss, Length: 92, dtype: int64

# %% [markdown]
# In this perticular Capital_loss column there are 95% zero values so let me drop this column.

# %%
#Droping Capital_loss column
df = df.drop(["Capital_loss"],axis=1)

# %%
df.head(3)
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
#
#         Marital_status          Occupation    Relationship    Race    Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#    Hours_per_week  Native_country  Income
# 0              13   United-States   <=50K
# 1              40   United-States   <=50K
# 2              40   United-States   <=50K

# %%
df.shape
# Out:
# (32560, 13)

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32560.0      38.581634      13.640642     17.0      28.0
# Fnlwgt          32560.0  189781.814373  105549.764924  12285.0  117831.5
# Education_num   32560.0      10.080590       2.572709      1.0       9.0
# Hours_per_week  32560.0      40.437469      12.347618      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# Fnlwgt          178363.0  237054.5  1484705.0
# Education_num       10.0      12.0       16.0
# Hours_per_week      40.0      45.0       99.0

# %% [markdown]
# **Visualization:**

# %%
# Separating numerical columns after dropping 2 columns
numerical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_columns.append(i)
print(numerical_columns)
# Out:
# ['Age', 'Fnlwgt', 'Education_num', 'Hours_per_week']

# %%
#Distribution plot for all numerical columns
for i in df[numerical_columns]:              
    plt.figure(figsize = (8, 4))
    sns.distplot(df[i], bins = 10, color="g")
    plt.title(i)
    plt.show()

# %% [markdown]
# All columns have high skewness in it.Age column has less skewness compare to other columns.

# %%
#Count plot for Income
sns.countplot(df['Income']);

# %% [markdown]
# More number of people earn less than or equal to 50000

# %%
sns.countplot(x='Workclass',hue ='Income',data = df)
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# People working in private sector earn more income compare to all other sectors.

# %%
sns.countplot(x='Education',hue ='Income',data = df)
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# people with Bachelores,HS-grade and Some college education earn more income compare to all other category people.

# %%
sns.countplot(x='Marital_status',hue ='Income',data = df)
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# * maxium number of Married with spouse earn more than 50000
# * More number of never married people earn less than or equal to 50000 compare to all others

# %%
sns.countplot(x='Occupation',hue ='Income',data = df)
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# * In the occupations exec-managerial and prof-specialty almost equal number of people earn less than or equal to 50000 and more than 50000.
# * In rest of the occupations more number people earn less than or equal to 50000

# %%
sns.countplot(x='Relationship',hue ='Income',data = df)
plt.xticks(rotation =90)
plt.show()

# %%
sns.countplot(x='Race',hue ='Income',data = df)
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# White people earn far more than any other race people.

# %%
fig = plt.figure(figsize=(12,5))
sns.countplot(x='Native_country',hue ='Income',data = df)
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# Native people of US earn far more than any other country people.

# %%
sns.countplot(x='Sex',hue ='Income',data = df)
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# Male earn more than females.

# %%
fig,axes=plt.subplots(2,2,figsize=(12,10))

# Checking income with Fnlwgt
sns.barplot(x='Income',y='Fnlwgt',ax=axes[0,0],data=df,palette='ch:.25')

# Checking income with Capital_gain
sns.barplot(x='Income',y='Age',ax=axes[0,1],data=df,palette='Set2')

# Checking income with Capital_loss
sns.barplot(x='Income',y='Education_num',ax=axes[1,0],data=df,palette='Set2')

# Checking income with Hours_per_week
sns.barplot(x='Income',y='Hours_per_week',ax=axes[1,1],data=df,palette='ch:.25')
plt.show()

# %% [markdown]
# * With Fnlwgt the chance of getting income >50k and <=50k both are almost equal.
# * With Age the chance of getting >50k is high compared to chance of getting income <=50k.
# * With Education_num the chance of getting income >50k is very high than <=50k.
# * With hours_per_week also the chance of getting income >50k is high.

# %%
#pair ploting for df
sns.pairplot(df,hue="Income")

# %% [markdown]
# * As the age of the worker increses there is less chance to get more income,And also as the Fnlgwt increases then the chance to get income is decreaseing.
# * People with age above 70 has less chance of getting work and As the education number increases then the chance of getting income>50k is also high.

# %%
#Checking for outliers using boxplot
df.plot(rot = 90,kind='box',fontsize=14,figsize=(25,15),color='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are outliers in all the numerical columns

# %% [markdown]
# ### Removing outliers:

# %%
#creating column names with outliers as a list
dfoutliers=df[['Age','Fnlwgt','Education_num','Hours_per_week']]

# %% [markdown]
# ### i) Zscore method:

# %%
# removing outliers with zscore
z=np.abs(zscore(dfoutliers))
df_new=df[(z<3).all(axis=1)]
df_new.head(5)
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Hours_per_week  Native_country  Income
# 0              13   United-States   <=50K
# 1              40   United-States   <=50K
# 2              40   United-States   <=50K
# 3              40            Cuba   <=50K
# 4              40   United-States   <=50K

# %%
#Checking shape of new dataset
df_new.shape
# Out:
# (31461, 13)

# %%
#Checking dataloss in zscore method
Dataloss=(((32560-31461)/32560)*100)
Dataloss
# Out:
# 3.3753071253071254

# %% [markdown]
# ### Checking for skewness:

# %%
#Checking for skewness
df_new.skew()
# Out:
# Age               0.472279
# Fnlwgt            0.634828
# Education_num    -0.159752
# Hours_per_week   -0.341724
# dtype: float64

# %% [markdown]
# There is skewness in Fnlwgt column.

# %% [markdown]
# **Removing skewness using yeo-johnson method:**

# %%
# creating list as attributes with skewness.
fea=["Fnlwgt"]

# %%
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box_cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box_cox' or 'yeo-johnson'\n"

# %%
df_new[fea] = scaler.fit_transform(df_new[fea].values)

# %%
# to check skewness again
df_new[fea].skew()
# Out:
# Fnlwgt   -0.034507
# dtype: float64

# %%
# to Check distplot for skewed columns after removing skewness
sns.distplot(df_new[fea],color='g')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Label Encoding:

# %%
# Separating categorical columns in df_new
cat_col=[]
for i in df_new.dtypes.index:
    if df_new.dtypes[i]=='object':
        cat_col.append(i)
print(cat_col)
# Out:
# ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %%
LE=LabelEncoder()
df_new[cat_col]= df_new[cat_col].apply(LE.fit_transform)

# %%
df_new[cat_col].head()
# Out:
#    Workclass  Education  Marital_status  Occupation  Relationship  Race  Sex  \
# 0          5          8               2           4             0     4    1
# 1          3         10               0           6             1     4    1
# 2          3          1               2           6             0     2    1
# 3          3          8               2          10             5     2    0
# 4          3         11               2           4             5     4    0
#
#    Native_country  Income
# 0              38       0
# 1              38       0
# 2              38       0
# 3               4       0
# 4              38       0

# %%
df_new.head()
# Out:
#    Age  Workclass    Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          5 -1.114171          8             13               2
# 1   38          3  0.427192         10              9               0
# 2   53          3  0.607320          1              7               2
# 3   28          3  1.487719          8             13               2
# 4   37          3  1.048962         11             14               2
#
#    Occupation  Relationship  Race  Sex  Hours_per_week  Native_country  Income
# 0           4             0     4    1              13              38       0
# 1           6             1     4    1              40              38       0
# 2           6             0     2    1              40              38       0
# 3          10             5     2    0              40               4       0
# 4           4             5     4    0              40              38       0

# %% [markdown]
# ### Checking correlation using heat map:

# %%
df_new.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.038024 -0.066519  -0.000447       0.053361
# Workclass       0.038024   1.000000 -0.021654   0.004652       0.003831
# Fnlwgt         -0.066519  -0.021654  1.000000  -0.024191      -0.033150
# Education      -0.000447   0.004652 -0.024191   1.000000       0.356040
# Education_num   0.053361   0.003831 -0.033150   0.356040       1.000000
# Marital_status -0.286424  -0.020597  0.027732  -0.039094      -0.065568
# Occupation     -0.013628   0.017997  0.003595  -0.021625       0.112686
# Relationship   -0.268028  -0.056825  0.008287  -0.015121      -0.102497
# Race            0.030679   0.046295 -0.008299   0.015552       0.030849
# Sex             0.091664   0.070095  0.025290  -0.024911       0.016662
# Hours_per_week  0.097510   0.030311 -0.015566   0.061325       0.160483
# Native_country -0.001039  -0.001602 -0.061214   0.068374       0.054510
# Income          0.248351   0.003494 -0.004586   0.077526       0.337595
#
#                 Marital_status  Occupation  Relationship      Race       Sex  \
# Age                  -0.286424   -0.013628     -0.268028  0.030679  0.091664
# Workclass            -0.020597    0.017997     -0.056825  0.046295  0.070095
# Fnlwgt                0.027732    0.003595      0.008287 -0.008299  0.025290
# Education            -0.039094   -0.021625     -0.015121  0.015552 -0.024911
# Education_num        -0.065568    0.112686     -0.102497  0.030849  0.016662
# Marital_status        1.000000   -0.009028      0.185772 -0.067546 -0.127375
# Occupation           -0.009028    1.000000     -0.076199  0.007311  0.080495
# Relationship          0.185772   -0.076199      1.000000 -0.115216 -0.582940
# Race                 -0.067546    0.007311     -0.115216  1.000000  0.088642
# Sex                  -0.127375    0.080495     -0.582940  0.088642  1.000000
# Hours_per_week       -0.197532    0.071974     -0.263412  0.045331  0.239039
# Native_country       -0.017606   -0.004207     -0.010871  0.122051  0.002060
# Income               -0.198475    0.074643     -0.251506  0.072451  0.216665
#
#                 Hours_per_week  Native_country    Income
# Age                   0.097510       -0.001039  0.248351
# Workclass             0.030311       -0.001602  0.003494
# Fnlwgt               -0.015566       -0.061214 -0.004586
# Education             0.061325        0.068374  0.077526
# Education_num         0.160483        0.054510  0.337595
# Marital_status       -0.197532       -0.017606 -0.198475
# Occupation            0.071974       -0.004207  0.074643
# Relationship         -0.263412       -0.010871 -0.251506
# Race                  0.045331        0.122051  0.072451
# Sex                   0.239039        0.002060  0.216665
# Hours_per_week        1.000000        0.004413  0.242383
# Native_country        0.004413        1.000000  0.017698
# Income                0.242383        0.017698  1.000000

# %% [markdown]
# Above are the correlations of all the pair of features.To get better visualization on the correlation of features,let me plot it using heat map.

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(20,15))
sns.heatmap(df_new.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.1g', annot = True, linecolor="black",annot_kws={'size':10},cmap="coolwarm")
plt.yticks(rotation=0);

# %% [markdown]
# * There is no multicolinearity present in the data.
# * Workclass and Fnlwgt has very less correlation with target.
# * Native_country, Occupation, Race and Education has less correlation with target column.

# %%
#Droping less correlated column
df_new = df_new.drop(["Workclass"],axis=1)

# %% [markdown]
# **Separating features and label:**

# %%
x = df_new.drop("Income",axis=1)
y = df_new["Income"]

# %% [markdown]
# I have separated my target and independent columns.

# %% [markdown]
# **Scaling the data using standard scaler:**

# %%
# Data is scaled my data using standard scaler.
scaler=StandardScaler()
X = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %%
X.head()
# Out:
#         Age    Fnlwgt  Education  Education_num  Marital_status  Occupation  \
# 0  0.875057 -1.114171  -0.348344       1.154324       -0.403597   -0.609135
# 1 -0.025350  0.427192   0.245782      -0.459657       -1.733114   -0.136411
# 2  1.100158  0.607320  -2.427783      -1.266647       -0.403597   -0.136411
# 3 -0.775689  1.487719  -0.348344       1.154324       -0.403597    0.809038
# 4 -0.100384  1.048962   0.542845       1.557819       -0.403597   -0.609135
#
#    Relationship      Race       Sex  Hours_per_week  Native_country
# 0     -0.903178  0.391304  0.706601       -2.424121        0.254062
# 1     -0.281938  0.391304  0.706601       -0.008364        0.254062
# 2     -0.903178 -1.969806  0.706601       -0.008364        0.254062
# 3      2.203019 -1.969806 -1.415226       -0.008364       -5.457546
# 4      2.203019  0.391304 -1.415226       -0.008364        0.254062

# %% [markdown]
# **Balancing the target variable using oversampling:**

# %%
#Checking the value count of target column
y.value_counts()
# Out:
# 0    23853
# 1     7608
# Name: Income, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
SM = SMOTE()
X, y = SM.fit_resample(X,y)

# %%
# Checking the value counts again
y.value_counts()
# Out:
# 1    23853
# 0    23853
# Name: Income, dtype: int64

# %%
# Visualizing the data after oversampling
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# **Finding Best Random State and Accuracy:**

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.30, random_state =i)
    mod = RandomForestClassifier()
    mod.fit(X_train, y_train)
    pred = mod.predict(X_test)
    acc=accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.8842929010620458  on Random_state  194

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=maxRS)

# %% [markdown]
# **i) DecisionTreeClassifier:**

# %%
DTC=DecisionTreeClassifier()
DTC.fit(X_train,y_train)
preddt=DTC.predict(X_test)
print('Accuracy Score:',accuracy_score(y_test, preddt))
print('Confusion Matrix:',confusion_matrix(y_test, preddt))
print(classification_report(y_test,preddt))
# Out:
# Accuracy Score: 0.8326579094466182
# Confusion Matrix: [[5918 1183]
#  [1212 5999]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      7101
#            1       0.84      0.83      0.83      7211
#
#     accuracy                           0.83     14312
#    macro avg       0.83      0.83      0.83     14312
# weighted avg       0.83      0.83      0.83     14312

# %%
cm = confusion_matrix(y_test, preddt)

x_axis_labels = ["<=50",">50"]
y_axis_labels = ["<=50",">50"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Decision Tree Classifier')
plt.show()

# %% [markdown]
# We can see the true values and predicted values in Decision Tree Classifier model using confusion matrix.

# %% [markdown]
# **ii) RandomForestClassifier:**

# %%
RFC=RandomForestClassifier()
RFC.fit(X_train,y_train)
predrf=RFC.predict(X_test)
print('Accuracy Score:',accuracy_score(y_test, predrf))
print('Confusion Matrix:',confusion_matrix(y_test, predrf))
print(classification_report(y_test,predrf))
# Out:
# Accuracy Score: 0.8832448295136948
# Confusion Matrix: [[6176  925]
#  [ 746 6465]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      7101
#            1       0.87      0.90      0.89      7211
#
#     accuracy                           0.88     14312
#    macro avg       0.88      0.88      0.88     14312
# weighted avg       0.88      0.88      0.88     14312

# %%
cm = confusion_matrix(y_test, predrf)

x_axis_labels = ["<=50",">50"]
y_axis_labels = ["<=50",">50"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Random Forest Classifier')
plt.show()

# %% [markdown]
# We can see the true values and predicted values in Random Forest Classifier model using confusion matrix.

# %% [markdown]
# **iii) SupportVectorClassifier:**

# %%
SV=SVC()
SV.fit(X_train,y_train)
predsv=SV.predict(X_test)
print('Accuracy Score:',accuracy_score(y_test, predsv))
print('Confusion Matrix:',confusion_matrix(y_test, predsv))
print(classification_report(y_test,predsv))
# Out:
# Accuracy Score: 0.82427333705981
# Confusion Matrix: [[5398 1703]
#  [ 812 6399]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81      7101
#            1       0.79      0.89      0.84      7211
#
#     accuracy                           0.82     14312
#    macro avg       0.83      0.82      0.82     14312
# weighted avg       0.83      0.82      0.82     14312

# %%
cm = confusion_matrix(y_test, predrf)

x_axis_labels = ["<=50",">50"]
y_axis_labels = ["<=50",">50"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Random Forest Classifier')
plt.show()

# %% [markdown]
# We can see the true values and predicted values in Support vector Classifier model using confusion matrix.

# %% [markdown]
# **iv) K-Neighbor Classifier:**

# %%
knn=KNN()
knn.fit(X_train,y_train)
predkn=knn.predict(X_test)
print('Accuracy Score:',accuracy_score(y_test, predkn))
print('Confusion Matrix:',confusion_matrix(y_test, predkn))
print(classification_report(y_test,predkn))
# Out:
# Accuracy Score: 0.8425097820011179
# Confusion Matrix: [[5463 1638]
#  [ 616 6595]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.77      0.83      7101
#            1       0.80      0.91      0.85      7211
#
#     accuracy                           0.84     14312
#    macro avg       0.85      0.84      0.84     14312
# weighted avg       0.85      0.84      0.84     14312

# %%
cm = confusion_matrix(y_test, predkn)

x_axis_labels = ["<=50",">50"]
y_axis_labels = ["<=50",">50"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for K-Neighbor Classifier')
plt.show()

# %% [markdown]
# We can see the true values and predicted values in KNN Classifier model using confusion matrix.

# %% [markdown]
# **Cross Validation Score:**

# %%
# cv score for Decision Tree Classifier
print(cross_val_score(DTC,X,y,cv=5).mean())
# Out:
# 0.8309455835905144

# %%
# cv score for Random Forest Classifier
print(cross_val_score(RFC,X,y,cv=5).mean())
# Out:
# 0.8793249076216005

# %%
# cv score for Support Vector Classifier
print(cross_val_score(SV,X,y,cv=5).mean())
# Out:
# 0.8166269344114736

# %%
# cv score for KNN Classifier
print(cross_val_score(knn,X,y,cv=5).mean())
# Out:
# 0.8466024500687179

# %% [markdown]
# **Hyper Parameter tuning:**

# %%
#Giving the parameters list for RFC model.
parameter = {'criterion':['gini','entropy'],
             'max_depth': [10,15,20,25],
             'n_estimators':[100,200,300,400],
             'max_features': ["auto","sqrt","log2"]}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameter,cv=5)

# %%
# training the model
GCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 15, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300, 400]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 25,
#  'max_features': 'sqrt',
#  'n_estimators': 300}

# %%
Final_mod=RandomForestClassifier(criterion='gini',max_depth=25, max_features='auto', n_estimators=200)
Final_mod.fit(X_train,y_train)
pred=Final_mod.predict(X_test)
acc=accuracy_score(y_test, pred)

print(acc*100)
# Out:
# 88.2685858021241

# %% [markdown]
# I got best model as RFC and i got the accuracy 88.26% after tunning which is good.!!!!

# %%
# Plotting for all the models used here
from sklearn import datasets 
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import plot_roc_curve 
disp = plot_roc_curve(RFC,X_test,y_test)
plot_roc_curve(knn, X_test, y_test, ax=disp.ax_)     # ax_=Axes with confusion matrix
plot_roc_curve(SV, X_test, y_test, ax=disp.ax_)
plot_roc_curve(DTC, X_test, y_test, ax=disp.ax_)

plt.legend(prop={'size':11}, loc='lower right')
plt.show()

# %% [markdown]
# Above is the ROC curves for all the models that i have predicted.And the AUC values can also be seen in the plot.

# %% [markdown]
# **Saving the model:**

# %%
#Saving the model as .pkl file
import joblib
joblib.dump(Final_mod,"Census_income.pkl")
# Out:
# ['Census_income.pkl']

# %% [markdown]
# I have saved the model as Census_income.

# %% [markdown]
# **Predictions:**

# %%
# Loading the saved model
model=joblib.load("Census_income.pkl")

#Prediction
prediction = model.predict(X_test)
prediction
# Out:
# array([0, 1, 0, ..., 0, 1, 1])

# %%
pd.DataFrame([model.predict(X_test)[:],y_test[:]],index=["Predicted","Actual"])
# Out:
#            0      1      2      3      4      5      6      7      8      \
# Predicted      0      1      0      0      0      1      1      1      1
# Actual         0      0      0      1      0      1      1      1      1
#
#            9      ...  14302  14303  14304  14305  14306  14307  14308  14309  \
# Predicted      0  ...      0      0      0      1      1      1      1      0
# Actual         0  ...      0      1      0      1      1      0      1      0
#
#            14310  14311
# Predicted      1      1
# Actual         1      1
#
# [2 rows x 14312 columns]

# %% [markdown]
# Above are the predicted values and the actual values.They are almost similar.
